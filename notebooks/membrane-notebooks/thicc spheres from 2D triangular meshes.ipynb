# %% [markdown]
# # TODO: thicc configurations/spheres from 2D triangular meshes
# Tim Tyree<br>
# 7.??.2020

# %%
# TODO(theory): how do I best approximate the surface tension forces with a body-centered spring triangular lattice 
# ^that being which we can set to the input triangular mesh resulting from clinical impedance measurement, who's to see?

# %%
#TODO: import spherical mesh
#TODO: body centered vertices
#TODO: displace a constant distance inward from the normal of the barycentric vertices
#nota bene: ^this choice is prone to locking from the "inverted triangle problem", which is solved by the right constitutive model.  
# The corotated linear hyperelastic model is prone to the "inverted triangle problem".

#TODO: save as mesh with user-defined thicc_configuration invertable class, 
# which encodes the map of the original triangular surface world space, $X\in\Omega_0$

#TODO: now simple model development for the corotated linear elastic model.

# %%
#create a virtual environment using django==2.1
# !brew install pipenv
# !pipenv install django==2.1
# Out:
# Updating Homebrew...
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/services).
# ==> New Formulae
# act                 eksctl              ksync               reg
# arb                 fennel              ldpl                scw@1
# argo                functionalplus      logcli              sdns
# argocd              gateway-go          loki                simdjson
# chalk-cli           golangci-lint       never               thanos
# chart-testing       gradle-profiler     ngs                 wgcf
# clair               hy                  notmuch-mutt        yj
# copilot             jimtcl              oci-cli             z.lua
# cortex              jinx                pipgrip
# duckscript          jsonnet-bundler     promtail
# ==> Updated Formulae
# Updated 2094 formulae.
# ==> Deleted Formulae
# sflowtool
#
# ==> Downloading https://homebrew.bintray.com/bottles/gdbm-1.18.1_1.mojave.bottle
# ...

# %% [markdown]
# # TODO: Applying newmark time stepping to ^that system
# - TODO(theory): consider what models can show the equivallence of spring force models of surface-tension forces.  what is the unit normal at a node?
#     - what are the local cell rules that minimize the action, free energy, or other constrained system of poisson-boltzmann guage-fields.

# %%
#*******************************************************************************
#
time_values = np.arrange(0,tmax,dt)
nt = len(time_values)
ndof = mesh.vertices # 2D triangular  mesh
# TODO: ndof = # for a 3D tetrahedral mesh
# TODO: consider ndof where each dof is an edge for spring forces or a face for surface-tension forces

x=np.zeros((nt,ndof),float)
y=np.zeros((nt,ndof),float)
a=np.zeros((nt,ndof),float)


x[i,:]=d0
y[i,:]=v0



##########################################################################

d,v,a =Newmark_force(M,C,K,FFI,force_dof,v0,d0,dt,nt,ndof)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-c6c97ca6bc71> in <module>
#       1 #*******************************************************************************
#       2 #
# ----> 3 time_values = np.arrange(0,tmax,dt)
#       4 nt = len(time_values)
#       5 ndof = mesh.vertices # 2D triangular  mesh
#
# AttributeError: module 'numpy' has no attribute 'arrange'
